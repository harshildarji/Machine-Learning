# %% [markdown]
# ### [Explore overfitting and underfitting](https://www.tensorflow.org/tutorials/keras/overfit_and_underfit)

# %% [markdown]
# The most common ways to prevent overfitting in neural networks:
# - Get more training data,
# - **Reduce the capacity of the network**,
# - **Add weight regularization**,
# - **Add dropout**,
# - Data augmentation,
# - Batch normalization.

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

# %%
print(tf.__version__)
# Out:
# 1.12.0

# %% [markdown]
# #### Load the dataset

# %%
NUM_WORDS = 10000

# %%
(train_data, train_labels), (test_data, test_labels) = keras.datasets.imdb.load_data(num_words=NUM_WORDS)

# %%
def multi_hot_seq(sequences, dimension):
    results = np.zeros((len(sequences), dimension))
    for i, word_indices in enumerate(sequences):
        results[i, word_indices] = 1.0
    return results

# %%
train_data = multi_hot_seq(train_data, dimension=NUM_WORDS)
test_data = multi_hot_seq(test_data, dimension=NUM_WORDS)

# %%
plt.plot(train_data[0])

# %% [markdown]
# #### Baseline model

# %%
baseline_model = keras.Sequential([
    keras.layers.Dense(16, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

# %%
baseline_model.compile(optimizer='adam',
                      loss='binary_crossentropy',
                      metrics=['accuracy', 'binary_crossentropy'])

# %%
baseline_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                160016
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseline_history = baseline_model.fit(train_data, train_labels, epochs=20, batch_size=512, validation_data=(test_data, test_labels), verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 14s - loss: 0.4427 - acc: 0.8203 - binary_crossentropy: 0.4427 - val_loss: 0.3084 - val_acc: 0.8813 - val_binary_crossentropy: 0.3084
# Epoch 2/20
#  - 13s - loss: 0.2251 - acc: 0.9169 - binary_crossentropy: 0.2251 - val_loss: 0.2862 - val_acc: 0.8860 - val_binary_crossentropy: 0.2862
# Epoch 3/20
#  - 8s - loss: 0.1670 - acc: 0.9417 - binary_crossentropy: 0.1670 - val_loss: 0.3010 - val_acc: 0.8825 - val_binary_crossentropy: 0.3010
# Epoch 4/20
#  - 8s - loss: 0.1335 - acc: 0.9544 - binary_crossentropy: 0.1335 - val_loss: 0.3334 - val_acc: 0.8767 - val_binary_crossentropy: 0.3334
# Epoch 5/20
#  - 8s - loss: 0.1120 - acc: 0.9626 - binary_crossentropy: 0.1120 - val_loss: 0.3666 - val_acc: 0.8704 - val_binary_crossentropy: 0.3666
# Epoch 6/20
#  - 9s - loss: 0.0924 - acc: 0.9720 - binary_crossentropy: 0.0924 - val_loss: 0.4013 - val_acc: 0.8663 - val_binary_crossentropy: 0.4013
# Epoch 7/20
#  - 9s - loss: 0.0761 - acc: 0.9785 - binary_crossentropy: 0.0761 - val_loss: 0.4559 - val_acc: 0.8586 - val_binary_crossentropy: 0.4559
# Epoch 8/20
#  - 10s - loss: 0.0639 - acc: 0.9823 - binary_crossentropy: 0.0639 - val_loss: 0.4889 - val_acc: 0.8598 - val_binary_crossentropy: 0.4889
# Epoch 9/20
#  - 10s - loss: 0.0528 - acc: 0.9873 - binary_crossentropy: 0.0528 - val_loss: 0.5311 - val_acc: 0.8562 - val_binary_crossentropy: 0.5311
# Epoch 10/20
#  - 11s - loss: 0.0438 - acc: 0.9908 - binary_crossentropy: 0.0438 - val_loss: 0.5832 - val_acc: 0.8525 - val_binary_crossentropy: 0.5832
# Epoch 11/20
#  - 11s - loss: 0.0383 - acc: 0.9918 - binary_crossentropy: 0.0383 - val_loss: 0.6251 - val_acc: 0.8529 - val_binary_crossentropy: 0.6251
# Epoch 12/20
#  - 9s - loss: 0.0297 - acc: 0.9946 - binary_crossentropy: 0.0297 - val_loss: 0.6706 - val_acc: 0.8514 - val_binary_crossentropy: 0.6706
# Epoch 13/20
#  - 9s - loss: 0.0233 - acc: 0.9962 - binary_crossentropy: 0.0233 - val_loss: 0.7119 - val_acc: 0.8486 - val_binary_crossentropy: 0.7119
# Epoch 14/20
#  - 9s - loss: 0.0185 - acc: 0.9978 - binary_crossentropy: 0.0185 - val_loss: 0.7527 - val_acc: 0.8477 - val_binary_crossentropy: 0.7527
# Epoch 15/20
#  - 9s - loss: 0.0145 - acc: 0.9989 - binary_crossentropy: 0.0145 - val_loss: 0.7982 - val_acc: 0.8468 - val_binary_crossentropy: 0.7982
# Epoch 16/20
#  - 10s - loss: 0.0112 - acc: 0.9992 - binary_crossentropy: 0.0112 - val_loss: 0.8394 - val_acc: 0.8476 - val_binary_crossentropy: 0.8394
# Epoch 17/20
#  - 11s - loss: 0.0090 - acc: 0.9998 - binary_crossentropy: 0.0090 - val_loss: 0.8768 - val_acc: 0.8450 - val_binary_crossentropy: 0.8768
# Epoch 18/20
#  - 11s - loss: 0.0069 - acc: 0.9998 - binary_crossentropy: 0.0069 - val_loss: 0.9121 - val_acc: 0.8452 - val_binary_crossentropy: 0.9121
# Epoch 19/20
#  - 11s - loss: 0.0053 - acc: 0.9999 - binary_crossentropy: 0.0053 - val_loss: 0.9450 - val_acc: 0.8464 - val_binary_crossentropy: 0.9450
# Epoch 20/20
#  - 10s - loss: 0.0043 - acc: 1.0000 - binary_crossentropy: 0.0043 - val_loss: 0.9780 - val_acc: 0.8452 - val_binary_crossentropy: 0.9780

# %% [markdown]
# #### Smaller model

# %%
small_model = keras.Sequential([
    keras.layers.Dense(4, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(4, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

# %%
small_model.compile(optimizer='adam',
                   loss='binary_crossentropy',
                   metrics=['accuracy', 'binary_crossentropy'])

# %%
small_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 4)                 40004
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 40,029
# Trainable params: 40,029
# Non-trainable params: 0
# _________________________________________________________________

# %%
small_history = small_model.fit(train_data, train_labels, epochs=20, batch_size=512, validation_data=(test_data, test_labels), verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 16s - loss: 0.6163 - acc: 0.7622 - binary_crossentropy: 0.6163 - val_loss: 0.5252 - val_acc: 0.8348 - val_binary_crossentropy: 0.5252
# Epoch 2/20
#  - 9s - loss: 0.4236 - acc: 0.8708 - binary_crossentropy: 0.4236 - val_loss: 0.3801 - val_acc: 0.8682 - val_binary_crossentropy: 0.3801
# Epoch 3/20
#  - 9s - loss: 0.3038 - acc: 0.8996 - binary_crossentropy: 0.3038 - val_loss: 0.3168 - val_acc: 0.8828 - val_binary_crossentropy: 0.3168
# Epoch 4/20
#  - 9s - loss: 0.2425 - acc: 0.9182 - binary_crossentropy: 0.2425 - val_loss: 0.2926 - val_acc: 0.8863 - val_binary_crossentropy: 0.2926
# Epoch 5/20
#  - 9s - loss: 0.2060 - acc: 0.9304 - binary_crossentropy: 0.2060 - val_loss: 0.2851 - val_acc: 0.8872 - val_binary_crossentropy: 0.2851
# Epoch 6/20
#  - 10s - loss: 0.1800 - acc: 0.9389 - binary_crossentropy: 0.1800 - val_loss: 0.2827 - val_acc: 0.8879 - val_binary_crossentropy: 0.2827
# Epoch 7/20
#  - 9s - loss: 0.1601 - acc: 0.9469 - binary_crossentropy: 0.1601 - val_loss: 0.2870 - val_acc: 0.8867 - val_binary_crossentropy: 0.2870
# Epoch 8/20
#  - 10s - loss: 0.1438 - acc: 0.9523 - binary_crossentropy: 0.1438 - val_loss: 0.2947 - val_acc: 0.8853 - val_binary_crossentropy: 0.2947
# Epoch 9/20
#  - 10s - loss: 0.1309 - acc: 0.9567 - binary_crossentropy: 0.1309 - val_loss: 0.3045 - val_acc: 0.8828 - val_binary_crossentropy: 0.3045
# Epoch 10/20
#  - 11s - loss: 0.1185 - acc: 0.9623 - binary_crossentropy: 0.1185 - val_loss: 0.3184 - val_acc: 0.8783 - val_binary_crossentropy: 0.3184
# Epoch 11/20
#  - 12s - loss: 0.1083 - acc: 0.9667 - binary_crossentropy: 0.1083 - val_loss: 0.3297 - val_acc: 0.8778 - val_binary_crossentropy: 0.3297
# Epoch 12/20
#  - 11s - loss: 0.0987 - acc: 0.9702 - binary_crossentropy: 0.0987 - val_loss: 0.3470 - val_acc: 0.8740 - val_binary_crossentropy: 0.3470
# Epoch 13/20
#  - 9s - loss: 0.0901 - acc: 0.9739 - binary_crossentropy: 0.0901 - val_loss: 0.3595 - val_acc: 0.8731 - val_binary_crossentropy: 0.3595
# Epoch 14/20
#  - 9s - loss: 0.0827 - acc: 0.9768 - binary_crossentropy: 0.0827 - val_loss: 0.3765 - val_acc: 0.8706 - val_binary_crossentropy: 0.3765
# Epoch 15/20
#  - 9s - loss: 0.0755 - acc: 0.9797 - binary_crossentropy: 0.0755 - val_loss: 0.3932 - val_acc: 0.8698 - val_binary_crossentropy: 0.3932
# Epoch 16/20
#  - 11s - loss: 0.0689 - acc: 0.9823 - binary_crossentropy: 0.0689 - val_loss: 0.4116 - val_acc: 0.8683 - val_binary_crossentropy: 0.4116
# Epoch 17/20
#  - 9s - loss: 0.0630 - acc: 0.9848 - binary_crossentropy: 0.0630 - val_loss: 0.4308 - val_acc: 0.8658 - val_binary_crossentropy: 0.4308
# Epoch 18/20
#  - 9s - loss: 0.0572 - acc: 0.9873 - binary_crossentropy: 0.0572 - val_loss: 0.4528 - val_acc: 0.8635 - val_binary_crossentropy: 0.4528
# Epoch 19/20
#  - 9s - loss: 0.0522 - acc: 0.9892 - binary_crossentropy: 0.0522 - val_loss: 0.4692 - val_acc: 0.8638 - val_binary_crossentropy: 0.4692
# Epoch 20/20
#  - 10s - loss: 0.0474 - acc: 0.9906 - binary_crossentropy: 0.0474 - val_loss: 0.4902 - val_acc: 0.8623 - val_binary_crossentropy: 0.4902

# %% [markdown]
# #### Larger model

# %%
large_model = keras.Sequential([
    keras.layers.Dense(512, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(512, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

# %%
large_model.compile(optimizer='adam',
                   loss='binary_crossentropy',
                   metrics=['accuracy', 'binary_crossentropy'])

# %%
large_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 512)               5120512
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 5,383,681
# Trainable params: 5,383,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
large_history = large_model.fit(train_data, train_labels, epochs=20, batch_size=512, validation_data=(test_data, test_labels), verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 52s - loss: 0.3481 - acc: 0.8524 - binary_crossentropy: 0.3481 - val_loss: 0.2969 - val_acc: 0.8801 - val_binary_crossentropy: 0.2969
# Epoch 2/20
#  - 49s - loss: 0.1413 - acc: 0.9488 - binary_crossentropy: 0.1413 - val_loss: 0.3565 - val_acc: 0.8645 - val_binary_crossentropy: 0.3565
# Epoch 3/20
#  - 49s - loss: 0.0493 - acc: 0.9856 - binary_crossentropy: 0.0493 - val_loss: 0.4309 - val_acc: 0.8676 - val_binary_crossentropy: 0.4309
# Epoch 4/20
#  - 49s - loss: 0.0081 - acc: 0.9990 - binary_crossentropy: 0.0081 - val_loss: 0.5634 - val_acc: 0.8709 - val_binary_crossentropy: 0.5634
# Epoch 5/20
#  - 49s - loss: 9.2941e-04 - acc: 1.0000 - binary_crossentropy: 9.2941e-04 - val_loss: 0.6577 - val_acc: 0.8713 - val_binary_crossentropy: 0.6577
# Epoch 6/20
#  - 55s - loss: 2.4597e-04 - acc: 1.0000 - binary_crossentropy: 2.4597e-04 - val_loss: 0.7015 - val_acc: 0.8706 - val_binary_crossentropy: 0.7015
# Epoch 7/20
#  - 52s - loss: 1.4286e-04 - acc: 1.0000 - binary_crossentropy: 1.4286e-04 - val_loss: 0.7309 - val_acc: 0.8708 - val_binary_crossentropy: 0.7309
# Epoch 8/20
#  - 54s - loss: 9.5949e-05 - acc: 1.0000 - binary_crossentropy: 9.5949e-05 - val_loss: 0.7564 - val_acc: 0.8712 - val_binary_crossentropy: 0.7564
# Epoch 9/20
#  - 53s - loss: 6.7637e-05 - acc: 1.0000 - binary_crossentropy: 6.7637e-05 - val_loss: 0.7804 - val_acc: 0.8714 - val_binary_crossentropy: 0.7804
# Epoch 10/20
#  - 52s - loss: 4.9397e-05 - acc: 1.0000 - binary_crossentropy: 4.9397e-05 - val_loss: 0.8011 - val_acc: 0.8715 - val_binary_crossentropy: 0.8011
# Epoch 11/20
#  - 55s - loss: 3.7220e-05 - acc: 1.0000 - binary_crossentropy: 3.7220e-05 - val_loss: 0.8205 - val_acc: 0.8715 - val_binary_crossentropy: 0.8205
# Epoch 12/20
#  - 52s - loss: 2.8740e-05 - acc: 1.0000 - binary_crossentropy: 2.8740e-05 - val_loss: 0.8382 - val_acc: 0.8714 - val_binary_crossentropy: 0.8382
# Epoch 13/20
#  - 54s - loss: 2.2755e-05 - acc: 1.0000 - binary_crossentropy: 2.2755e-05 - val_loss: 0.8532 - val_acc: 0.8714 - val_binary_crossentropy: 0.8532
# Epoch 14/20
#  - 54s - loss: 1.8401e-05 - acc: 1.0000 - binary_crossentropy: 1.8401e-05 - val_loss: 0.8680 - val_acc: 0.8713 - val_binary_crossentropy: 0.8680
# Epoch 15/20
#  - 51s - loss: 1.5133e-05 - acc: 1.0000 - binary_crossentropy: 1.5133e-05 - val_loss: 0.8807 - val_acc: 0.8712 - val_binary_crossentropy: 0.8807
# Epoch 16/20
#  - 53s - loss: 1.2653e-05 - acc: 1.0000 - binary_crossentropy: 1.2653e-05 - val_loss: 0.8921 - val_acc: 0.8713 - val_binary_crossentropy: 0.8921
# Epoch 17/20
#  - 54s - loss: 1.0699e-05 - acc: 1.0000 - binary_crossentropy: 1.0699e-05 - val_loss: 0.9041 - val_acc: 0.8713 - val_binary_crossentropy: 0.9041
# Epoch 18/20
#  - 55s - loss: 9.1793e-06 - acc: 1.0000 - binary_crossentropy: 9.1793e-06 - val_loss: 0.9134 - val_acc: 0.8716 - val_binary_crossentropy: 0.9134
# Epoch 19/20
#  - 53s - loss: 7.9268e-06 - acc: 1.0000 - binary_crossentropy: 7.9268e-06 - val_loss: 0.9226 - val_acc: 0.8715 - val_binary_crossentropy: 0.9226
# Epoch 20/20
#  - 53s - loss: 6.9263e-06 - acc: 1.0000 - binary_crossentropy: 6.9263e-06 - val_loss: 0.9317 - val_acc: 0.8712 - val_binary_crossentropy: 0.9317

# %% [markdown]
# #### Plot histories

# %%
def plot(histories, key='binary_crossentropy'):
    plt.figure(figsize=(16, 10))
    
    for name, history in histories:
        val = plt.plot(history.epoch, history.history['val_'+key], ':', label=name.title()+' Validation')
        plt.plot(history.epoch, history.history[key], label=name.title()+' Train', color=val[0].get_color())
        
    plt.xlabel('Epochs')
    plt.ylabel(key.replace('_', ' ').title())
    plt.xlim(0, max(history.epoch))
    plt.legend()

# %%
plot([('baseline', baseline_history), ('smaller', small_history), ('larger', large_history)])

# %% [markdown]
# #### Weigh regularization

# %%
l2_model = keras.Sequential([
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001), activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001), activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

# %%
l2_model.compile(optimizer='adam',
                loss='binary_crossentropy',
                metrics=['accuracy', 'binary_crossentropy'])

# %%
l2_model_history = l2_model.fit(train_data, train_labels, epochs=20, batch_size=512, validation_data=(test_data, test_labels), verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 28s - loss: 0.5016 - acc: 0.8120 - binary_crossentropy: 0.4593 - val_loss: 0.3687 - val_acc: 0.8796 - val_binary_crossentropy: 0.3232
# Epoch 2/20
#  - 12s - loss: 0.2971 - acc: 0.9130 - binary_crossentropy: 0.2476 - val_loss: 0.3362 - val_acc: 0.8875 - val_binary_crossentropy: 0.2841
# Epoch 3/20
#  - 12s - loss: 0.2527 - acc: 0.9314 - binary_crossentropy: 0.1986 - val_loss: 0.3406 - val_acc: 0.8859 - val_binary_crossentropy: 0.2850
# Epoch 4/20
#  - 10s - loss: 0.2298 - acc: 0.9406 - binary_crossentropy: 0.1727 - val_loss: 0.3541 - val_acc: 0.8819 - val_binary_crossentropy: 0.2962
# Epoch 5/20
#  - 10s - loss: 0.2181 - acc: 0.9461 - binary_crossentropy: 0.1587 - val_loss: 0.3660 - val_acc: 0.8790 - val_binary_crossentropy: 0.3057
# Epoch 6/20
#  - 10s - loss: 0.2059 - acc: 0.9508 - binary_crossentropy: 0.1451 - val_loss: 0.3821 - val_acc: 0.8750 - val_binary_crossentropy: 0.3210
# Epoch 7/20
#  - 10s - loss: 0.1995 - acc: 0.9537 - binary_crossentropy: 0.1373 - val_loss: 0.3952 - val_acc: 0.8729 - val_binary_crossentropy: 0.3324
# Epoch 8/20
#  - 11s - loss: 0.1927 - acc: 0.9574 - binary_crossentropy: 0.1293 - val_loss: 0.4078 - val_acc: 0.8706 - val_binary_crossentropy: 0.3441
# Epoch 9/20
#  - 11s - loss: 0.1881 - acc: 0.9568 - binary_crossentropy: 0.1239 - val_loss: 0.4251 - val_acc: 0.8697 - val_binary_crossentropy: 0.3604
# Epoch 10/20
#  - 12s - loss: 0.1866 - acc: 0.9583 - binary_crossentropy: 0.1212 - val_loss: 0.4373 - val_acc: 0.8656 - val_binary_crossentropy: 0.3715
# Epoch 11/20
#  - 11s - loss: 0.1823 - acc: 0.9606 - binary_crossentropy: 0.1161 - val_loss: 0.4487 - val_acc: 0.8654 - val_binary_crossentropy: 0.3819
# Epoch 12/20
#  - 12s - loss: 0.1792 - acc: 0.9614 - binary_crossentropy: 0.1124 - val_loss: 0.4710 - val_acc: 0.8599 - val_binary_crossentropy: 0.4040
# Epoch 13/20
#  - 10s - loss: 0.1789 - acc: 0.9606 - binary_crossentropy: 0.1110 - val_loss: 0.4693 - val_acc: 0.8622 - val_binary_crossentropy: 0.4011
# Epoch 14/20
#  - 12s - loss: 0.1710 - acc: 0.9640 - binary_crossentropy: 0.1029 - val_loss: 0.4784 - val_acc: 0.8594 - val_binary_crossentropy: 0.4108
# Epoch 15/20
#  - 14s - loss: 0.1653 - acc: 0.9676 - binary_crossentropy: 0.0977 - val_loss: 0.4917 - val_acc: 0.8590 - val_binary_crossentropy: 0.4241
# Epoch 16/20
#  - 13s - loss: 0.1642 - acc: 0.9677 - binary_crossentropy: 0.0962 - val_loss: 0.5036 - val_acc: 0.8572 - val_binary_crossentropy: 0.4354
# Epoch 17/20
#  - 12s - loss: 0.1628 - acc: 0.9678 - binary_crossentropy: 0.0946 - val_loss: 0.5145 - val_acc: 0.8553 - val_binary_crossentropy: 0.4459
# Epoch 18/20
#  - 12s - loss: 0.1624 - acc: 0.9676 - binary_crossentropy: 0.0935 - val_loss: 0.5332 - val_acc: 0.8543 - val_binary_crossentropy: 0.4639
# Epoch 19/20
#  - 13s - loss: 0.1606 - acc: 0.9676 - binary_crossentropy: 0.0912 - val_loss: 0.5311 - val_acc: 0.8583 - val_binary_crossentropy: 0.4615
# Epoch 20/20
#  - 12s - loss: 0.1601 - acc: 0.9682 - binary_crossentropy: 0.0900 - val_loss: 0.5450 - val_acc: 0.8544 - val_binary_crossentropy: 0.4746

# %%
plot([('baseline', baseline_history), ('l2', l2_model_history)])

# %% [markdown]
# #### Dropout

# %%
dpt_model = keras.Sequential([
    keras.layers.Dense(16, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

# %%
dpt_model.compile(optimizer='adam',
                 loss='binary_crossentropy',
                 metrics=['accuracy', 'binary_crossentropy'])

# %%
dpt_model_history = dpt_model.fit(train_data, train_labels, epochs=20, batch_size=512, validation_data=(test_data, test_labels), verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 27s - loss: 0.6366 - acc: 0.6220 - binary_crossentropy: 0.6366 - val_loss: 0.4959 - val_acc: 0.8526 - val_binary_crossentropy: 0.4959
# Epoch 2/20
#  - 11s - loss: 0.4686 - acc: 0.7984 - binary_crossentropy: 0.4686 - val_loss: 0.3408 - val_acc: 0.8783 - val_binary_crossentropy: 0.3408
# Epoch 3/20
#  - 13s - loss: 0.3620 - acc: 0.8680 - binary_crossentropy: 0.3620 - val_loss: 0.2894 - val_acc: 0.8873 - val_binary_crossentropy: 0.2894
# Epoch 4/20
#  - 14s - loss: 0.2892 - acc: 0.8987 - binary_crossentropy: 0.2892 - val_loss: 0.2739 - val_acc: 0.8898 - val_binary_crossentropy: 0.2739
# Epoch 5/20
#  - 13s - loss: 0.2490 - acc: 0.9169 - binary_crossentropy: 0.2490 - val_loss: 0.2740 - val_acc: 0.8876 - val_binary_crossentropy: 0.2740
# Epoch 6/20
#  - 12s - loss: 0.2200 - acc: 0.9263 - binary_crossentropy: 0.2200 - val_loss: 0.2859 - val_acc: 0.8861 - val_binary_crossentropy: 0.2859
# Epoch 7/20
#  - 13s - loss: 0.1909 - acc: 0.9381 - binary_crossentropy: 0.1909 - val_loss: 0.3062 - val_acc: 0.8862 - val_binary_crossentropy: 0.3062
# Epoch 8/20
#  - 15s - loss: 0.1714 - acc: 0.9437 - binary_crossentropy: 0.1714 - val_loss: 0.3134 - val_acc: 0.8842 - val_binary_crossentropy: 0.3134
# Epoch 9/20
#  - 12s - loss: 0.1540 - acc: 0.9493 - binary_crossentropy: 0.1540 - val_loss: 0.3438 - val_acc: 0.8821 - val_binary_crossentropy: 0.3438
# Epoch 10/20
#  - 12s - loss: 0.1384 - acc: 0.9540 - binary_crossentropy: 0.1384 - val_loss: 0.3570 - val_acc: 0.8807 - val_binary_crossentropy: 0.3570
# Epoch 11/20
#  - 16s - loss: 0.1282 - acc: 0.9557 - binary_crossentropy: 0.1282 - val_loss: 0.3667 - val_acc: 0.8798 - val_binary_crossentropy: 0.3667
# Epoch 12/20
#  - 9s - loss: 0.1139 - acc: 0.9622 - binary_crossentropy: 0.1139 - val_loss: 0.4047 - val_acc: 0.8788 - val_binary_crossentropy: 0.4047
# Epoch 13/20
#  - 9s - loss: 0.1064 - acc: 0.9641 - binary_crossentropy: 0.1064 - val_loss: 0.4432 - val_acc: 0.8767 - val_binary_crossentropy: 0.4432
# Epoch 14/20
# WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.740787). Check your callbacks.
# WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.370394). Check your callbacks.
#  - 23s - loss: 0.0987 - acc: 0.9660 - binary_crossentropy: 0.0987 - val_loss: 0.4215 - val_acc: 0.8778 - val_binary_crossentropy: 0.4215
# Epoch 15/20
#  - 10s - loss: 0.0969 - acc: 0.9653 - binary_crossentropy: 0.0969 - val_loss: 0.4473 - val_acc: 0.8779 - val_binary_crossentropy: 0.4473
# Epoch 16/20
#  - 11s - loss: 0.0878 - acc: 0.9696 - binary_crossentropy: 0.0878 - val_loss: 0.4786 - val_acc: 0.8762 - val_binary_crossentropy: 0.4786
# Epoch 17/20
#  - 11s - loss: 0.0823 - acc: 0.9712 - binary_crossentropy: 0.0823 - val_loss: 0.4957 - val_acc: 0.8763 - val_binary_crossentropy: 0.4957
# Epoch 18/20
#  - 10s - loss: 0.0798 - acc: 0.9709 - binary_crossentropy: 0.0798 - val_loss: 0.5050 - val_acc: 0.8758 - val_binary_crossentropy: 0.5050
# Epoch 19/20
#  - 10s - loss: 0.0734 - acc: 0.9745 - binary_crossentropy: 0.0734 - val_loss: 0.5552 - val_acc: 0.8762 - val_binary_crossentropy: 0.5552
# Epoch 20/20
#  - 10s - loss: 0.0729 - acc: 0.9722 - binary_crossentropy: 0.0729 - val_loss: 0.5562 - val_acc: 0.8747 - val_binary_crossentropy: 0.5562

# %%
plot([('baseline', baseline_history), ('dropout', dpt_model_history)])
